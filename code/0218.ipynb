# %% [markdown]
# !PWV in mm!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [Schroeder-Westwater-1991] file:///C:/Users/RECHEN/Downloads/noaa_32511_DS1.pdf\

# %% [markdown]
# 1. find PWV in mm
# 2. then find the polt of diff models
